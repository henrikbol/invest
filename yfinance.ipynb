# %%
import yfinance as yf

# %%
novo = yf.Ticker("NOVO-B.CO")

# %%
novo.quarterly_income_stmt
# Out:
#                                                        2024-03-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                          0.204
# Normalized EBITDA                                   36906000000.0
# Net Income From Continuing Operation Net Minori...  25407000000.0
# Reconciled Depreciation                              2914000000.0
# Reconciled Cost Of Revenue                           9916000000.0
# EBITDA                                              36906000000.0
# EBIT                                                33992000000.0
# Net Interest Income                                    72000000.0
# Interest Expense                                     2074000000.0
# Interest Income                                      2146000000.0
# Normalized Income                                   25407000000.0
# Net Income From Continuing And Discontinued Ope...  25407000000.0
# ...

# %%
novo.info
# Out:
# {'address1': 'Novo Alle 1',
#  'city': 'Bagsvaerd',
#  'zip': '2880',
#  'country': 'Denmark',
#  'phone': '45 44 44 88 88',
#  'website': 'https://www.novonordisk.com',
#  'industry': 'Biotechnology',
#  'industryKey': 'biotechnology',
#  'industryDisp': 'Biotechnology',
#  'sector': 'Healthcare',
#  'sectorKey': 'healthcare',
#  'sectorDisp': 'Healthcare',
# ...

# %%
novo.history(period="1mo")
# Out:
#                                   Open         High          Low        Close  \
# Date
# 2024-06-10 00:00:00+02:00   979.000000   991.299988   979.000000   988.400024
# 2024-06-11 00:00:00+02:00   992.000000   997.400024   979.200012   982.000000
# 2024-06-12 00:00:00+02:00   984.000000   993.500000   981.799988   989.599976
# 2024-06-13 00:00:00+02:00   991.200012   993.099976   979.700012   979.700012
# 2024-06-14 00:00:00+02:00   984.700012   996.900024   977.000000   991.000000
# 2024-06-17 00:00:00+02:00   991.000000   995.400024   980.500000   980.500000
# 2024-06-18 00:00:00+02:00   980.000000   983.700012   972.799988   981.200012
# 2024-06-19 00:00:00+02:00   973.700012   984.900024   972.400024   984.200012
# 2024-06-20 00:00:00+02:00   985.000000   993.799988   979.599976   993.799988
# 2024-06-21 00:00:00+02:00   983.200012   993.599976   978.599976   987.900024
# 2024-06-24 00:00:00+02:00   988.000000   995.799988   982.000000   988.400024
# ...
